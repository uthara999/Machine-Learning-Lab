# %% [markdown]
# <a href="https://colab.research.google.com/github/uthara999/Machine-Learning-Lab/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

# %%
data=[['apple',10,240],['orange',15,150],['grapes',14,80],['pineapple',10,70]]
df1=pd.DataFrame(data,columns=['Friuts_name',"Quantity",'Unit_Price'])
df1
# Out:
#   Friuts_name  Quantity  Unit_Price
# 0       apple        10         240
# 1      orange        15         150
# 2      grapes        14          80
# 3   pineapple        10          70

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Friuts_name  4 non-null      object
#  1   Quantity     4 non-null      int64
#  2   Unit_Price   4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
df1.describe()
# Out:
#         Quantity  Unit_Price
# count   4.000000    4.000000
# mean   12.250000  135.000000
# std     2.629956   78.528127
# min    10.000000   70.000000
# 25%    10.000000   77.500000
# 50%    12.000000  115.000000
# 75%    14.250000  172.500000
# max    15.000000  240.000000

# %%
data={'Fruit_name':['apple','orange','grapes','pineapple'],'Quantity':[10,15,14,10],'Unit_price':[240,150,80,70]}
df2=pd.DataFrame(data)

# %%
df2
# Out:
#   Fruit_name  Quantity  Unit_price
# 0      apple        10         240
# 1     orange        15         150
# 2     grapes        14          80
# 3  pineapple        10          70

# %%
df3=pd.DataFrame(data,index=['f1','f2','f3','f4'])

# %%
data=[{'Fruit_name':'apple','Quantity':10,'Unit_price':240},{'Fruit_name':'orange','Quantity':15,'Unit_price':150}]

# %%
df4=pd.DataFrame(data)

# %%
df4
# Out:
#   Fruit_name  Quantity  Unit_price
# 0      apple        10         240
# 1     orange        15         150

# %%
row={'Fruit_name':'litchy','Quantity':10,'Unit_price':80}
df4=df4.append(row,ignore_index=True)
df4
# Out:
# <ipython-input-12-0b9fc25699b7>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df4=df4.append(row,ignore_index=True)
#   Fruit_name  Quantity  Unit_price
# 0      apple        10         240
# 1     orange        15         150
# 2     litchy        10          80

# %%
df4.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df4.loc[len(df4.index)]=['cherry',5,500]
df4
# Out:
#   Fruit_name  Quantity  Unit_price
# 0      apple        10         240
# 1     orange        15         150
# 2     litchy        10          80
# 3     cherry         5         500

# %%
data=[{'Fruit_name':'mango','Quantity':13,'Unit_price':140},{'Fruit_name':'strawberry','Quantity': 8 ,'Unit_price':250}]
df5=pd.DataFrame(data)
df4=pd.concat([df4,df5],ignore_index=True)
df4
# Out:
#    Fruit_name  Quantity  Unit_price
# 0       apple        10         240
# 1      orange        15         150
# 2      litchy        10          80
# 3      cherry         5         500
# 4       mango        13         140
# 5  strawberry         8         250

# %%
df4['Total_price']=df4['Quantity']*df4['Unit_price']
df4
# Out:
#    Fruit_name  Quantity  Unit_price  Total_price
# 0       apple        10         240         2400
# 1      orange        15         150         2250
# 2      litchy        10          80          800
# 3      cherry         5         500         2500
# 4       mango        13         140         1820
# 5  strawberry         8         250         2000

# %%
df4.columns=['Fruit','Qty','Uprice','Totprice']
df4
# Out:
#         Fruit  Qty  Uprice  Totprice
# 0       apple   10     240      2400
# 1      orange   15     150      2250
# 2      litchy   10      80       800
# 3      cherry    5     500      2500
# 4       mango   13     140      1820
# 5  strawberry    8     250      2000

# %%
df4=df4.rename(columns={"fruit":"fruitname"})
df4
# Out:
#         Fruit  Qty  Uprice  Totprice
# 0       apple   10     240      2400
# 1      orange   15     150      2250
# 2      litchy   10      80       800
# 3      cherry    5     500      2500
# 4       mango   13     140      1820
# 5  strawberry    8     250      2000

# %%
df4=df4.rename({'Qty':'Quantity','Uprice':'Unitprice'},axis='columns')
df4
# Out:
#         Fruit  Quantity  Unitprice  Totprice
# 0       apple        10        240      2400
# 1      orange        15        150      2250
# 2      litchy        10         80       800
# 3      cherry         5        500      2500
# 4       mango        13        140      1820
# 5  strawberry         8        250      2000

# %%
df4.index=['F1','F6','F5','F4','F3','F2']
df4
# Out:
#     Unitprice  Totprice  Quantity       Fruit
# F1        240      2400        10       apple
# F6        150      2250        15      orange
# F5         80       800        10      litchy
# F4        500      2500         5      cherry
# F3        140      1820        13       mango
# F2        250      2000         8  strawberry

# %%
df4=df4.sort_index(ascending=False,axis=1)
df4
# Out:
#     Unitprice  Totprice  Quantity       Fruit
# F1        240      2400        10       apple
# F6        150      2250        15      orange
# F5         80       800        10      litchy
# F4        500      2500         5      cherry
# F3        140      1820        13       mango
# F2        250      2000         8  strawberry

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df=pd.read_csv('/content/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.shape
# Out:
# (150, 6)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.loc[5]
# Out:
# Id                         6
# SepalLengthCm            5.4
# SepalWidthCm             3.9
# PetalLengthCm            1.7
# PetalWidthCm             0.4
# Species          Iris-setosa
# Name: 5, dtype: object

# %%
df.plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
df['SepalLengthCm'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
